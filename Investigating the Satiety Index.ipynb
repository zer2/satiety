# %% [markdown]
# # Calculating the Satiety Index
#
# One of the most important concepts in nutrition is the satiety index- the ratio between how filling a food is vs. how many calories it contains. People who eat satiating foods tend to consume fewer calories overall, helping them lose weight. Understanding satiety is also important for gaining weight, since eating un-filling foods allows for the consumption of excess calories
#
# Unfortunately, the satiety index is difficult to measure. [Some work](https://www.researchgate.net/publication/15701207_A_Satiety_Index_of_common_foods) has been done to measure the satiety index of common foods, but no comprehensive research exists. The closest I have found is [this article](https://optimisingnutrition.com/calculating-satiety/) which uses a public dataset to investigate the satiation of macronutrients.
#
# If we are interested in how satiating various foods are, we can take a similar approach to the aforementioned article, except look at individual foods instead of macronutrients. We will use the same dataset from kaggle, which has records of 10k people's eating habits plus daily calorie goals. We will create a sparse (day record x food consumed) matrix, and use linear regression to estimate how strongly each food contributed to achieving the corresponding calorie goals.

# %%
import json
from datetime import datetime
import pandas as pd
import re
from scipy.sparse import vstack
from scipy.sparse import csr_matrix, csc_matrix
from scipy.sparse.linalg import lsqr
from itertools import compress
from operator import itemgetter

import os
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
import nltk
from sklearn.cluster import KMeans
from sentence_transformers import SentenceTransformer
from rake_nltk import Rake

# %% [markdown]
# # Part 1: Reading the data and transforming it into df format
#
# The data's raw form is a tab-seperated text file with json-like entries for nutrition logs. We are interested only in the names of foods consumed and their calorie content, so we can transform the json logs into series mapping foods to calories.

# %%
df = pd.read_csv('../data/mfp-diaries.tsv', sep = '\t', header = None)
df.columns = ['PERSON_ID','DATE','NUTRITION','GOALS']

def get_float_value(x):
    return int(re.sub( ',','',x)) #it is important to store vars as ints instead of strs, to conserve memory later 

def flatten(xss):
    return [x for xs in xss for x in xs]

goal_calories = [json.loads(x['GOALS'])['total'][0]['value'] for k,x in df.iterrows()]

start = datetime.now()
calorie_records = [pd.Series(
                                {y['name'] : get_float_value(y['nutritions'][0]['value'])
                                 for y in flatten([z['dishes'] for z in json.loads(x['NUTRITION'])])
                                }
                            )
                for k, x in df.iterrows()]
print(datetime.now() - start)
# Out:
# 0:03:25.172914

# %% [markdown]
# # Part 2: Creating a sparse matrix from the records
#
# Our goal is to have a dataframe with a row for each daily journal and a column for each food consumed, but that is infeasible. There are ~600k daily entries, and ~1M unique foods listed. While the vast majority of cell contents would be simply zero, the resulting dense dataframe would still be far too large to hold in traditional memory.
#
# Fortunately, we can use a sparse representation to have a dataframe-esque object without explicitly writing every zero.

# %%
start = datetime.now()

all_foods = set().union(*[list(c.index) for c in calorie_records])
tot_foods = len(all_foods)
mapping = {food : i for food, i in zip(all_foods,range(tot_foods))}
sparse_records = [csr_matrix((calorie_record.values,
                               ([0] * len(calorie_record)
                                ,[mapping[z] for z in calorie_record.index]
                               )
                              )
                             ,shape = (1, tot_foods)
                            ) for calorie_record in calorie_records]
sparse_matrix = vstack(sparse_records)
print(datetime.now() - start)
# Out:
# 0:02:00.643453

# %% [markdown]
# # Part 3: Calculating inferred satiety indexes by food
#
# We overcame the technical hurdle of holding the dataset in memory, but there is also a mathematical hurdle, which is that we have more columns than rows. We don't want to suffer from the curse of dimensionality so we need to reduce our features somehow.
#
# One approach is to lump all of the rare foods together. This will add some noise to the model, but it will also allow the model to focus on the more common foods, and hopefully come up with solid estimates

# %%
start = datetime.now()
food_counts = sparse_matrix.sum(axis = 0)
food_count_significant = [f >= 1000 for f in food_counts] #we will lump all the 'insignificant' foods together
significant_food_matrix = sparse_matrix[:, food_count_significant[0].tolist()[0]]
insignificant_food_matrix = sparse_matrix[:, (~food_count_significant[0]).tolist()[0]]

insignificant_food_calories = insignificant_food_matrix.sum(axis = 1)

adjusted_significant_food_matrix = hstack([significant_food_matrix, insignificant_food_calories])
res = lsqr(adjusted_significant_food_matrix
           , goal_calories
           , x0 = [1] * adjusted_significant_food_matrix.shape[1])

significant_foods = list(compress(list(mapping.keys()),food_count_significant[0].tolist()[0]))
significant_food_ratios = pd.Series(res[0], index = significant_foods + ['Other'])
print(datetime.now() - start)
# Out:
# 0:07:38.607748

# %%
significant_food_ratios.sort_values(ascending = False)
# Out:
# Fresh - Green Onion, Chopped, 1/4 cup                                                               22.564728
# Kirkland Signature (Costco) - Extra Strength Glucosamine Hci 1500 Mg With Msm 1500 Mg, 2 Tablets    12.591241
# Tesco - Organic Spinach, 50 g                                                                        9.197528
# Generic - Tea With 40ml Whole Milk, 1 Mug                                                            8.924278
# Generic - Green Beens Boiled, 3 cup (125 grams)                                                      8.692831
#                                                                                                       ...
# Kirkland - Vitamin C 500 Mg Chewable, 2 tablet                                                      -5.455760
# Nescafe Taster's Choice - Single Serve Packet - Hazelnut Instant Coffee, 2 packet                   -5.476055
# Generic - Rice, Jasmin, Boiled, 150 g                                                               -6.706598
# Classic - Tomato, 100 g                                                                             -8.144594
# 2/7 black beans, 0.5 serving(s)                                                                     -8.535910
# Length: 156904, dtype: float64

# %%
significant_food_matrix.sum()/sparse_matrix.sum()
# Out:
# 0.604063870539085

# %% [markdown]
# Even after reducing our features significantly (from 1M to ~157k), the results still look fairly unreliable. We don't have the option of excluding more foods because we are already cutting out 40% of all calories consumed, and cutting out more than that would add excessive noise. So what other options do we have?

# %% [markdown]
# # Part 4: Finding satiety index by category
#
# One step we could take is categorizing foods by type. "Potato" and "Sweet Potato" could be mixed together, for example .
#
# To do this we will embed the food descriptions with Sentence-Bert, then categorize them using K-means clustering. Using LDA is another option but it is not appropriate because it assigns multiple topics to each input document, which is not what we want. We will also rake-nltk to summarize the categories for more understandability. In an ideal world we would do this analysis for every food, but it would take a long time so we will use the same procedure as before, limiting to only the common foods

# %%
nltk.download('omw-1.4')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')

stemmer = SnowballStemmer("english")

additional_stopwords = {'oz','ozs','cup','cups','small','medium','large','gram','grams','pound','serving','tbsp'
                       ,'container','order','serving(s)','tbls','mini','inch','servings','standard','white','black'
                       ,'regular','homemade'}
full_stopwords = gensim.parsing.preprocessing.STOPWORDS.union(additional_stopwords)

'''
Write a function to perform the pre processing steps on the entire dataset
'''
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

# Tokenize and lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in full_stopwords and len(token) > 3:
            result.append(lemmatize_stemming(token))
            
    return result

def get_summary_of_cluster(cluster):
    text = ". ".join([mapping_inverted[x] for x in cluster_map[cluster]])
    rake_nltk_var.extract_keywords_from_text(text)
    keyword_extracted = rake_nltk_var.get_ranked_phrases()
    return keyword_extracted[0]
# Out:
# [nltk_data] Downloading package omw-1.4 to C:\Users\Zach
# [nltk_data]     Rosenof\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Zach
# [nltk_data]     Rosenof\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Zach
# [nltk_data]     Rosenof\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Zach
# [nltk_data]     Rosenof\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
start = datetime.now()

processed_docs = []

for doc in significant_foods:
    processed_docs.append(preprocess(doc))

model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = model.encode([z if len(z) > 1 else (z*2 if len(z) == 1 else ['blank','blank']) for z in processed_docs]) 

km = KMeans(n_clusters = 300)
km.fit(embeddings)

cluster_map = {}
for food, label in zip(significant_foods, km.labels_):
    cluster_map[label] = cluster_map.get(label,[]) + [mapping[food]]
cluster_list = list(cluster_map.keys())

clumped_matrix = np.concatenate([sparse_matrix[:,cluster_map[cluster]].sum(axis = 1) for cluster in cluster_list]
                                , axis = 1)
clumped_matrix = np.concatenate([clumped_matrix, insignificant_food_calories]
                                , axis = 1)

res = np.linalg.lstsq(clumped_matrix, goal_calories)    

mapping_inverted = {v: k for k, v in mapping.items()}
res_final = pd.Series({get_summary_of_cluster(cluster) : res[0][cluster_list.index(cluster)] 
                       for cluster in cluster_list})

print(datetime.now() - start)
# Out:
# C:\Users\Zach Rosenof\AppData\Local\Temp\ipykernel_17492\1611286040.py:24: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   res = np.linalg.lstsq(clumped_matrix, goal_calories)
# 0:45:03.891982

# %%
pd.set_option('display.max_rows', 300)
res_final.sort_values(ascending = False)
# Out:
# pure protein soft baked protein bar double chocolate peanut butter crunch                         2.296790
# golden crinkle french fried potatoes +, 6 ounces                                                  1.240076
# muscletech six star pro nutrition elite series                                                    1.214433
# whey iso burst double chocolate royal protein drink mix                                           1.155434
# korean bbq pulled pork quinoa rice pot                                                            1.155210
# extra crunchy natural super chunk peanut butter spread                                            1.141851
# ready ® fully cooked frozen southwestern chicken breast strips                                    1.134474
# ligne gourmande noir 70 %, 2 carrés                                                               1.120221
# updated 12 feb 2014 ), 78 g                                                                       1.113397
# double rich chocolate ), 50 g 1 rounded scoop                                                     1.105482
# original unsweetened almond coconut milk -, 2 cup                                                 1.104688
# 75 oz ., 78 g ), 1 bar                                                                            1.095486
# meal ), 1 tbsp .. fpl food ground chuck beef                                                      1.088812
# extra special clotted cream fudge west country yogurt                                             1.088687
# chewy chocolate chunk 90 calorie granola bar                                                      1.087258
# eat smart frosted cinnamon caramel crunch bar                                                     1.084269
# ready whole grain medley pouch -- brown                                                           1.082032
# super advanced creatine high performance fruit punch                                              1.072234
# nutrition heart healthy mix *, 2 oz .. six star pro nutrition                                     1.071721
# meat lovers pizza gluten free milk free lactose free                                              1.067377
# chicken breast salad w ranch dressing                                                             1.067305
# popcorn jolly time weight watchers 100 calorie                                                    1.066492
# go sharp cheddar cheese 2 oz ., 2 oz .. slimming world cowboy hotpot                              1.063891
# extra crunch peanut butter 2 tbs ., 2 tbs .. marcos                                               1.063102
# gluten free bread super seeded multi grain                                                        1.061056
# skinless baked chicken breast 4oz ., 4 oz .. butterball                                           1.060519
# bread sara lee whole grain white                                                                  1.059141
# cocoa classics warm oatmeal cookie hot cocoa mix                                                  1.058822
# 0 cal spray ), 4 extra large egg white                                                            1.057964
# market basket plain greek yogurt 0 %, 5                                                           1.057204
# milk reduced mild cheddar reduced fat cheese                                                      1.056825
# smoked 16 thin cut streaky rindless bacon rashers                                                 1.054509
# dechaine orange cranberry steel cut oats                                                          1.052850
# lipton onion soup oven roasted potatoes                                                           1.052614
# old fashioned hamburger buns unsliced white 53g                                                   1.051788
# 21 whole grains thins 60 calories                                                                 1.050335
# natural low sodium creamy peanut butter -, 99 grams                                               1.049946
# diet cola chicken – recipes – slimming world                                                      1.049338
# field fresh 4 single steamers classic garden mix                                                  1.045999
# chocolate peanut butter non dairy frozen desert                                                   1.045956
# 100 calorie right bites mini fudge stripe cookies                                                 1.044741
# cholesterol free egg white pasta noodles 99                                                       1.043929
# yogur satisfacción pro natural edulcorado vitalinea                                               1.042773
# jumbo eggs )( 285g serve ), 1 serving                                                             1.042559
# accurate vt ), 4 large egg                                                                        1.042105
# organic dark chocolate mint 60 %, 1 container                                                     1.041867
# spinach breakfast power sandwich *( sk ), 1 sandwich                                              1.041015
# peanut caramel cluster bar (* 3 net carbs ), 1 bar                                                1.040602
# dark chocolate crunchy clusters berry medley flavors                                              1.040111
# australian light reduced fat tasty chedar cheese slices                                           1.039839
# beer ), 24 oz .. homemade apple crisp                                                             1.039740
# iorgute com creme adoçado e calda de limão siciliano                                              1.039611
# reduced fat finely shredded fiesta blend cheese 2 %, 14 g                                         1.039105
# pro performance soy protein 95 unflavored isolated soy protein mix                                1.038371
# bulletproof coffee avec mct et beurre bio                                                         1.038300
# old tyme butcher shop hickory smoked bacon                                                        1.038224
# bake sweet potato sm ., 1 small                                                                   1.038039
# onion flavoured maize snack rings 150g ), 75 g                                                    1.038018
# smart ones smart beginnings english muffin sandwich turkey sausage                                1.038009
# high protein low carb hplc bar caramel rough                                                      1.036666
# incl 180 ml semi skim milk ), 1 sachet                                                            1.036391
# 145g drained wt ), 145 g drained weight                                                           1.035822
# intense dark chocolate midnight reverie 86 %, 2 sections                                          1.033958
# supreme protein peanut butter pretzel twist 96 g net carbs                                        1.032578
# gnc pro performance ® amp amplified wheybolic extreme 60                                          1.032130
# muscle blend weight loss meal replacement shake formula                                           1.032031
# 牛乳 （ 普通 ）, 200 g                                                                                  1.031561
# eas myoplex lite 17 oz french vanilla                                                             1.031529
# website 24apr2014 ), 1 original size order                                                        1.031428
# poulet 165gr patate douce 100 gr et légumes                                                       1.031216
# northamptonshire cured sliced honey roast ham                                                     1.030754
# soft taco flour tortillas 41g serving size ), 41 g                                                1.028976
# thai organic crystal hom mali brown rice                                                          1.028671
# plak kaas jong belegen 30 +, 1 plak                                                               1.028181
# per restaurant nutrition app ), 1                                                                 1.027447
# *** honey dew melon ***, 1 cup                                                                    1.027352
# ground turkey meat 93 %/ 7 %, 6 oz .. foster farms                                                1.026211
# n serve lite original fully cooked sausage links                                                  1.025930
# honey wheat 40 calories per slice bread net carbs                                                 1.025311
# new recipe 2013 ), 400 g                                                                          1.025008
# patatas fritas en aceite de oliva                                                                 1.024902
# sunny buns super deluxe hamburger bun                                                             1.024794
# butchers selection irish slow cook diced casserole beef                                           1.024781
# cinnamon ‘ n ’ raisin ™ biscuit                                                                   1.024751
# spinach cherry almond bleu salad kit                                                              1.024470
# lightly salted dry roasted peanuts heart healthy 4                                                1.024209
# mayo clinic marketplace chicken blt wrap                                                          1.023961
# chicken thigh quick stew crock pot                                                                1.023684
# beef loin top sirloin cap steak usda prime                                                        1.023593
# sweet kale salad mixed total pkg weight 880 grams srv                                             1.022918
# cacoa extra dark chocolate shell w                                                                1.022756
# small curd cottage cheese 4 %, 1 c                                                                1.022568
# frozen ), 76 g grilled sausage                                                                    1.022485
# elite series triple chocolate whey protein plus                                                   1.022425
# traditional black pudding slices *, 115                                                           1.022047
# rich milk chocolate (. 71oz ), 1 envelope                                                         1.021753
# wholemeal seeded batch loaf ), 94 g                                                               1.021201
# swiss miss classics milk chocolate mix packets                                                    1.020767
# butter top whole grain wheat bread -, 52 g                                                        1.020632
# oscar mayer deli fresh oven roasted turkey breast                                                 1.020564
# churn style chocolate chip cookie dough ice cream 1                                               1.020510
# ++ beef hot dog ++, 2 hot dog                                                                     1.020455
# special k cracker chips cheddar 110 calories per serving                                          1.020223
# cor performance red velvet cake batter whey protein                                               1.020146
# universal casein pro vanilla soft serve                                                           1.019887
# colossal new york stype cheesecake cherry top slice                                               1.019106
# big chewy peanut butter chocolate chip granola bar 42 g                                           1.018973
# lettuce picante ranch dressing cheese sour cream pico de gallo                                    1.018487
# big 100 colossal peanut butter pretzel meal replacement bar                                       1.018099
# cookie dough caramel crisp whey protein bar                                                       1.017939
# 1 miniature box (. 5 oz ).                                                                        1.017827
# carb balance whole wheat tortillas large 6 net carbs                                              1.017479
# incl est minerals ), 2 slice                                                                      1.017462
# carnivor beef protein isolate fruit punch flavor                                                  1.017369
# sugar free dark chocolate pecan delights minus sugar alcohols                                     1.017152
# low moisture part skim mozzarella cheese                                                          1.017000
# pc blue menu high fibre steel cut oatmeal                                                         1.016925
# miracle whip white bread ,, 1 sandwich                                                            1.016896
# blueberry dairy free yogurt alternative made                                                      1.016593
# betty crocker milk chocolate cake n frosting                                                      1.016276
# vanilla ice cream protein powder 5lbs ., 1 scoop                                                  1.015782
# natural cage free grain fed large brown eggs grade aa                                             1.015762
# 500g ), 75 grams uncooked 190 grams cooked                                                        1.015649
# heavy whipping cream ), 16 oz .. starbucks                                                        1.015522
# smart pop kettle korn single serve packet                                                         1.015264
# south beach diet gluten free chewy nut bar                                                        1.015262
# grass fed angus beef strip loin steak                                                             1.015234
# shock top twisted pretzel wheat                                                                   1.014990
# ++ fried chicken leg ++, 2 drumstick                                                              1.014659
# black garlic oil tonkotsu flavor instant noodles                                                  1.014476
# 7 oz ., 7 oz .. arbor mist                                                                        1.014411
# gnc pro performance ® amp ripped vitapak ® program                                                1.013856
# heb fully cooked sliced seasoned chicken breast sep fajitas                                       1.013583
# instant oatmeal lower sugar maple n brown sugar flavor packets                                    1.013234
# cassoulet de castelnaudary au confit de canard du sud                                             1.013187
# nip chee crackers -- real cheddar cheese cracker -- 4 pack                                        1.013074
# clean eating stuffed capsicum recipe move nourish believe                                         1.012837
# whole grain angel hair pasta *, 2 oz                                                              1.012680
# large cheddar crust honey bbq chicken pizza                                                       1.012628
# seven whole grains 90 second microwave pouch                                                      1.012416
# corrected sodium per label cms ), 3 breadsticks                                                   1.012210
# center cut filet migon lighter fare 6oz                                                           1.012190
# organic valley cage free omega 3 large brown eggs                                                 1.012046
# wheat free gluten free dairy free quick cooking oats                                              1.012035
# alaskan wild sockeye salmon pinwheel king crab stuffing                                           1.011961
# 1 heaping tsp ., 2 tsp .. wild oats                                                               1.011881
# 8 oz ., 1 pkg .. eureka baking company                                                            1.011826
# potato soup 100g 550g per serving 6                                                               1.011678
# dairy free coconut milk ice cream mint chip                                                       1.011536
# 200g per potato ), 200 g per potato                                                               1.011302
# icelandic style skyr strained non fat yogurt blueberry                                            1.011089
# boneless center cut pork loin chop thin slice                                                     1.011082
# fancy shredded mild cheddar cheese 5 lb                                                           1.010624
# quick added calories 150                                                                          1.010489
# reeses peanut butter chocolate cake cheesecake                                                    1.010282
# shredded wheat honey nut spoon size *, 1                                                          1.010257
# original shredded new york sharp cheddar cheese                                                   1.010106
# oven roasted shaved white turkey one pound bag                                                    1.009902
# 18 sc balsamic pineapple pot roast                                                                1.009701
# guacomole ), 1 regular size shell                                                                 1.009504
# beef brisket flat cut boneless usda choice cooked braised                                         1.009289
# minus sugar alcohols ), 1 bar                                                                     1.009127
# buffalo chicken dip *, 4 oz .. amf lanes                                                          1.008946
# homestyle chicken salad (( corrected )), 1 cup                                                    1.008677
# salad pockets whole wheat pita pockets                                                            1.008627
# cultured goat milk kefir blueberry pom acai                                                       1.008413
# nacho cheese white bean chips *, 28 g                                                             1.008380
# whole wheat whole grain bread 35 calories per slice                                               1.008176
# dutch chocolate fat free sugar free ice cream                                                     1.007851
# glazed chicken (* culinary collection ), 1 package                                                1.007672
# 6 "- 7 ")( 101g ), 1 banana medium                                                                1.006833
# jarlsberg lite deli thin sliced reduced fat swiss cheese                                          1.006829
# coldstone sweet cream coffee creamer ** updated sugar                                             1.006646
# corrected via mazzios site ), 2 piece                                                             1.006420
# weighing 151 g ).                                                                                 1.006191
# whole grain pecan banana bread muffin                                                             1.005963
# dymatize iso 100 birthday cake protein shake                                                      1.005934
# world famous pancakes ), 2 pancakes                                                               1.005823
# thai kitchen spring onion instant rice noodle soup                                                1.005650
# old fashioned potato ham chowder correct **, 1 container                                          1.005620
# 9 grain honey oat sweet onion teriyaki chicken ,, 6 inch                                          1.005351
# ski soleil mango layer high protein greek style yoghurt                                           1.005270
# parmesan baby reds mashed pot ., 1 cup                                                            1.005099
# 16 crackers per serving ), 16 crackers per serving                                                1.004901
# pistachio pudding powder sugar free fat free                                                      1.004810
# double chocolate brownie protein bar corr jan 2014                                                1.004760
# 10 wing (. 5 tsp seasoning ).                                                                     1.004625
# cup noodles 合味道 xo sauce seafood flavour xo醬海鮮味                                                   1.004477
# meat lasagna 11 oz ., 11 oz .. john west                                                          1.004462
# 3lb bacon velveeta ® patty meltdown                                                               1.004352
# boneless thin center cut pork chops                                                               1.004269
# tendercrisp chicken sand ., 250 g                                                                 1.003926
# ensure high protein shake creamy milk chocolate 14 fl oz                                          1.003915
# cage free organic extra large brown eggs                                                          1.003668
# greek style lite low fat natural yoghurt                                                          1.003589
# peanut butter *, 1 tbs .. creamy chicken gravy                                                    1.003306
# sugar added mint chocolate chip ice cream                                                         1.003002
# 22 slices ea 37g ave 1 slice serving ), 2 slice                                                   1.002659
# hot dog roll ), 1 roll                                                                            1.002605
# 270 g bag corrected ), 95 chips                                                                   1.002493
# taco night party pack ), 4 tacos                                                                  1.002408
# golden graham king size choc marshmallow treat bar                                                1.002182
# extra lean pork center cut loin filet                                                             1.002171
# triple dipper ™ big mouth ® bites w                                                               1.001987
# pasta mushroom mince peppers dolmio sauce                                                         1.001786
# spaghetti n turkey meat sauce *, 1 serving                                                        1.001777
# 70 calorie vending machine pack                                                                   1.001739
# instant coffee 2 tsp splenda sweetner skim milk                                                   1.001701
# gourmet chocolate chip cookie dough                                                               1.001662
# whole wheat tortilla 6 ", 2 tortilla 34 g .. savoy stir fry                                       1.001581
# curried kidney beans ), 1 cup                                                                     1.001456
# iowa girl eats ), 12 serving                                                                      1.001225
# 100 calorie thin crisps chocolate chip cookies                                                    1.000781
# boneless pork loin chops ., 8 oz .. publix brand                                                  1.000707
# meat free vegetable fingers *, 2 fingers                                                          1.000589
# lentil whole grain couscous soup lower sodium                                                     1.000583
# without tartar sauce ), 4 fillets plus fries                                                      1.000413
# peanut butter cup (. 5 pound cup ), 1                                                             1.000342
# 6 piece chicken nugget happy meal without drink                                                   1.000031
# everyday recipe starters turkey sausage polska kielbasa                                           1.000010
# 4 oz .. carrefour bio riz long de camargue                                                        1.000006
# 24 oz .. smoothie king peanut power plus strawberry                                               0.999932
# usda choice cab chuckeye center eye steak boneless                                                0.999880
# naturally hickory smoked thick cut bacon                                                          0.999869
# block mozzarella shredded natural low moisture part skim cheese fine cut                          0.999700
# per container may 18 2014 ), 1 container                                                          0.999582
# ® special k nourish ™ hot cereal maple brown sugar crunch                                         0.999477
# pollo marinara linguine whole wheat pasta                                                         0.999449
# green pepper pizza 14 ", 4 slice                                                                  0.999304
# modifications ), 16 fl oz .. starbucks medium vanilla latte                                       0.999300
# great organic grass fed beef hot dog                                                              0.999173
# authentic greek whole wheat flat bread                                                            0.998964
# whl grain english muffin ), 1 sandwich                                                            0.998737
# 8 wiltshire cured air dried unsmoked back bacon                                                   0.998452
# turkey wheat pepperjack spinach lettuce jalapeno green pepers mustard                             0.998305
# burrito bowl chicken brown rice clack beans fajita veggis tomato salsa corn salsa                 0.998252
# carolina cole slaw ), 2 sandwich                                                                  0.997928
# ef carmel cheese cake 350 */ 20 min                                                               0.997909
# mini energy bar white chocolate macadamia nut 28 g                                                0.997868
# panda paws creamy light ice cream                                                                 0.997853
# thin crispy crust bbq recipe chicken pizza new improved recipe                                    0.997815
# deep dish single serving pepperoni pizza                                                          0.997788
# rudis organic bakery whole grain wheat english muffins                                            0.997584
# pumpkin gooey butter cakes recipe gf df                                                           0.997560
# lunch kit tuna salad chunk white albacore tuna kit                                                0.997439
# bakery classics top sliced hot dog buns                                                           0.997366
# french bread pepperoni pizza corrected ****, 1 pizza                                              0.997342
# regular 300 g pkg ., 150 g                                                                        0.997138
# carmel bon bon pancakes 4 bacon 2 eggs hashbrown                                                  0.997133
# la plancha •, 200 gr .. presto salmon pasta                                                       0.996772
# best food choices ..., 1 bunch                                                                    0.996426
# super crunch chicken strip dinner -- corrected                                                    0.996273
# hand tossed medium pepperoni pizza extra pep ., 4 slice                                           0.996233
# junior cheeseburger deluxe -( correct ), 148 g                                                    0.995976
# sugar free dark fudge wafers *, 36 cookies                                                        0.995920
# english muffin applewood smoke chicken sausage patty egg whites sharp american cheese sandwich    0.995800
# turtles original pecan caramel clusters covered                                                   0.995742
# caesar parmigiano 45 calorie yogurt dressing                                                      0.995686
# iced dunkin ’ dark ® roast coffee                                                                 0.995607
# ancient whole grain tortilla wrap ** edit **, 122 g                                               0.995404
# single serving cup ), 2 oz .. udi                                                                 0.994609
# steakhouse onion rings -( 6 count )-, 158 grams                                                   0.994435
# premium sliced smoked atlantic nova salmon                                                        0.994143
# north atlantic cod basket 2 pc                                                                    0.993887
# chewy granola bars peanut butter chocolate ship                                                   0.993277
# extreme wellness high fiber low carb tortilla wrap                                                0.993203
# greek grilled chicken wrap osu union market                                                       0.992961
# 糯米 ， 香菇 ， 蛋黃 ， 瘦肉 ， 花生 ， 蘿蔔乾 ), 2                                                                 0.992594
# raisins peanuts sunflower seeds dates soy nuts ), 1 cup                                           0.992158
# 2 ), pico de gallo ), 1 salad                                                                     0.992128
# full meal per website ), 1 meal                                                                   0.991279
# delicious coconut milk ice cream coconut almond bar mini                                          0.989200
# crunchy popcorn shrimp -- lunch portion                                                           0.988946
# chocolate low fat ice cream sandwiches                                                            0.988917
# 1 mini chimi ), 3 mini chimi                                                                      0.987679
# abc bakery ), 3 cookies                                                                           0.987258
# biscuits complets au germe de blé                                                                 0.987190
# natural whole grain rolled oats ), 1                                                              0.986644
# fun size *, 1 fun size bars                                                                       0.986449
# hershey smores kit ), 3 full cracker sheets                                                       0.986212
# classic breakfast 2 eggs 3 strips bacon 2 pc whole wheat toast                                    0.986000
# 12 cakes per carton ), 2 cakes                                                                    0.985734
# per web site 20 nov 13 ).                                                                         0.984962
# corrected 23 sept 13 ), 2 slices                                                                  0.984395
# gluten free rice plus golden flax angel hair pasta                                                0.983905
# whole catch wild alaskan sockeye salmon fillet                                                    0.983447
# zuni red wine braised pot roast                                                                   0.983240
# nutty double chocolate layered granola bar                                                        0.983150
# gyoza ., 1 teishoku plate                                                                         0.983121
# delite crust pizza family size gourmet chicken garlic                                             0.982351
# hearty grains double fiber honey wheat english muffin                                             0.981901
# hamburger steak 4 oz ., 2 hamburger steak                                                         0.980939
# ever roast oven roasted chicken breast                                                            0.979101
# traditional new england clam chowder gluten free                                                  0.976905
# 180 g cooked (= 85 g uncooked ).                                                                  0.976180
# 6 oz .. gnc lowfat ice cream sandwiches                                                           0.970897
# sweet kale super 7 sweet kale vegetable salad mix                                                 0.970227
# 85g per packet dry ), 85 g                                                                        0.958524
# healthy goodness whole grain white bread                                                          0.952185
# cage free vegetarian fed hens grade                                                               0.951602
# dtype: float64

# %% [markdown]
# There is some interesting information here. Pure protein products at the top make sense superficially, and could indicate something real. However, the coefficients generally look close to one, suggesting that MyFitnessPal users are largely hitting their calorie targets regardless of what kinds of food they choose to eat.
#
# This is not necessarily an indictment on the concept of a satiety index. People who track their own calories are likely capable of adjusting their food intake against what it would be naturally to meet their calorie targets. They might even be mis-reporting their intake, consciously or unconsciously, to keep it in line with their goals
